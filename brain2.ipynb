# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Define the directories
train_dir = "Dataset/train"
val_dir = "Dataset/validation"
test_dir = "Dataset/test"

# Define the categories
categories = ["glioma", "meningioma", "notumor", "pituitary"]

# Visualize the distribution of tumor types in the training dataset
train_data = []
for category in categories:
    folder_path = os.path.join(train_dir, category)
    images = os.listdir(folder_path)
    count = len(images)
    train_data.append(pd.DataFrame({"Image": images, "Category": [category] * count, "Count": [count] * count}))
train_df = pd.concat(train_data, ignore_index=True)

plt.figure(figsize=(8, 6))
sns.barplot(data=train_df, x="Category", y="Count")
plt.title("Distribution of Tumor Types")
plt.xlabel("Tumor Type")
plt.ylabel("Count")
plt.show()

# Visualize sample images for each tumor type
plt.figure(figsize=(12, 8))
for i, category in enumerate(categories):
    folder_path = os.path.join(train_dir, category)
    image_path = os.path.join(folder_path, os.listdir(folder_path)[0])
    try:
        img = plt.imread(image_path)
        plt.subplot(2, 2, i + 1)
        plt.imshow(img)
        plt.title(category)
        plt.axis("off")
    except:
        continue
plt.tight_layout()
plt.show()

# Set the image size
image_size = (150, 150)

# Set the batch size and number of epochs
batch_size = 32
epochs = 50

# Set the learning rate
learning_rate = 0.001

# Data augmentation and preprocessing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode="nearest"
)

val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Create data generators
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical"
)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical"
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False
)

# Define the model architecture
model = Sequential([
    Conv2D(32, (3, 3), activation="relu", input_shape=(image_size[0], image_size[1], 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation="relu"),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation="relu"),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation="relu"),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation="relu"),
    Dropout(0.3),
    Dense(len(categories), activation="softmax")
])

# Compile the model with a specified learning rate
optimizer = Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"])

# Calculate steps dynamically
steps_per_epoch = np.ceil(train_generator.samples / batch_size).astype(int)
validation_steps = np.ceil(validation_generator.samples / batch_size).astype(int)
test_steps = np.ceil(test_generator.samples / batch_size).astype(int)

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_steps
)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(test_generator, steps=test_steps)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

# Visualize training history
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Found 17896 images belonging to 4 classes.
# Found 2167 images belonging to 4 classes.
# Found 4335 images belonging to 4 classes.
# /Users/arsalankhan/miniconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# /Users/arsalankhan/miniconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 134s 236ms/step - accuracy: 0.4682 - loss: 1.1555 - val_accuracy: 0.6198 - val_loss: 0.9371
# Epoch 2/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 39us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# 2025-01-19 20:41:26.779525: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# /Users/arsalankhan/miniconda3/lib/python3.12/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 2025-01-19 20:41:26.789012: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 142s 253ms/step - accuracy: 0.6715 - loss: 0.8245 - val_accuracy: 0.7628 - val_loss: 0.6296
# Epoch 4/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 2025-01-19 20:43:48.953250: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 20:43:48.955941: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 142s 251ms/step - accuracy: 0.7752 - loss: 0.6076 - val_accuracy: 0.8163 - val_loss: 0.4909
# Epoch 6/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 16us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 2025-01-19 20:46:10.489879: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 20:46:10.492704: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 150s 267ms/step - accuracy: 0.8222 - loss: 0.5059 - val_accuracy: 0.8279 - val_loss: 0.4703
# Epoch 8/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 17us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 2025-01-19 20:48:40.778386: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 20:48:40.781337: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 151s 269ms/step - accuracy: 0.8425 - loss: 0.4506 - val_accuracy: 0.8468 - val_loss: 0.4340
# Epoch 10/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 23us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 2025-01-19 20:51:11.794440: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 20:51:11.798018: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 151s 269ms/step - accuracy: 0.8538 - loss: 0.4165 - val_accuracy: 0.8837 - val_loss: 0.3074
# Epoch 12/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 23us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 2025-01-19 20:53:42.915279: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 20:53:42.918818: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 153s 272ms/step - accuracy: 0.8712 - loss: 0.3682 - val_accuracy: 0.8874 - val_loss: 0.2847
# Epoch 14/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 18us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 2025-01-19 20:56:15.690559: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 20:56:15.694064: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 157s 280ms/step - accuracy: 0.8752 - loss: 0.3562 - val_accuracy: 0.9188 - val_loss: 0.2239
# Epoch 16/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 26us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 2025-01-19 20:58:52.785427: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 20:58:52.791834: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 160s 285ms/step - accuracy: 0.8802 - loss: 0.3477 - val_accuracy: 0.9031 - val_loss: 0.2660
# Epoch 18/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 29us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 2025-01-19 21:01:33.187607: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 21:01:33.190787: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 164s 292ms/step - accuracy: 0.8824 - loss: 0.3317 - val_accuracy: 0.9229 - val_loss: 0.1990
# Epoch 20/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 39us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 2025-01-19 21:04:17.529485: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 21:04:17.544405: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 158s 281ms/step - accuracy: 0.8967 - loss: 0.3007 - val_accuracy: 0.9054 - val_loss: 0.2417
# Epoch 22/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 17us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 2025-01-19 21:06:55.353366: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 21:06:55.356605: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 156s 278ms/step - accuracy: 0.9004 - loss: 0.2965 - val_accuracy: 0.9202 - val_loss: 0.2275
# Epoch 24/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 17us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 2025-01-19 21:09:31.673390: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 21:09:31.676568: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 159s 283ms/step - accuracy: 0.8957 - loss: 0.2965 - val_accuracy: 0.9266 - val_loss: 0.1868
# Epoch 26/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 21us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 2025-01-19 21:12:10.841869: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 21:12:10.845957: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 160s 284ms/step - accuracy: 0.9044 - loss: 0.2731 - val_accuracy: 0.9151 - val_loss: 0.2081
# Epoch 28/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 21us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 2025-01-19 21:14:50.673081: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 21:14:50.678363: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 161s 286ms/step - accuracy: 0.9085 - loss: 0.2649 - val_accuracy: 0.9211 - val_loss: 0.1979
# Epoch 30/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 20us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 2025-01-19 21:17:31.500004: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 21:17:31.504203: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 159s 283ms/step - accuracy: 0.9134 - loss: 0.2591 - val_accuracy: 0.9289 - val_loss: 0.1928
# Epoch 32/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 18us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 2025-01-19 21:20:10.538785: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 21:20:10.541992: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 160s 284ms/step - accuracy: 0.9095 - loss: 0.2634 - val_accuracy: 0.9502 - val_loss: 0.1516
# Epoch 34/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 30us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 2025-01-19 21:22:50.204231: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 21:22:50.213420: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 160s 285ms/step - accuracy: 0.9136 - loss: 0.2542 - val_accuracy: 0.9395 - val_loss: 0.1649
# Epoch 36/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 24us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 2025-01-19 21:25:30.551572: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 21:25:30.555182: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 160s 284ms/step - accuracy: 0.9160 - loss: 0.2439 - val_accuracy: 0.9377 - val_loss: 0.1510
# Epoch 38/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 22us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 2025-01-19 21:28:10.128564: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 21:28:10.132200: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 172s 306ms/step - accuracy: 0.9155 - loss: 0.2479 - val_accuracy: 0.9363 - val_loss: 0.1740
# Epoch 40/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 48us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 2025-01-19 21:31:02.185508: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 21:31:02.199318: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 159s 282ms/step - accuracy: 0.9237 - loss: 0.2295 - val_accuracy: 0.9483 - val_loss: 0.1314
# Epoch 42/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 25us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 2025-01-19 21:33:40.918942: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 21:33:40.922416: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 163s 290ms/step - accuracy: 0.9231 - loss: 0.2272 - val_accuracy: 0.9492 - val_loss: 0.1361
# Epoch 44/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 42us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 2025-01-19 21:36:23.707552: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 21:36:23.721034: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 155s 275ms/step - accuracy: 0.9252 - loss: 0.2204 - val_accuracy: 0.9585 - val_loss: 0.1158
# Epoch 46/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 19us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 2025-01-19 21:38:58.256833: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 21:38:58.261173: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 154s 273ms/step - accuracy: 0.9266 - loss: 0.2181 - val_accuracy: 0.9502 - val_loss: 0.1279
# Epoch 48/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 23us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 2025-01-19 21:41:31.972968: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 21:41:31.977061: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 152s 271ms/step - accuracy: 0.9231 - loss: 0.2237 - val_accuracy: 0.9405 - val_loss: 0.1608
# Epoch 50/50
# 560/560 ━━━━━━━━━━━━━━━━━━━━ 0s 25us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# 2025-01-19 21:44:04.379844: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-19 21:44:04.384434: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.9303 - loss: 0.1792
# Test Loss: 0.1426030546426773
# Test Accuracy: 0.9497116208076477

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
import numpy as np

def plot_auc(model, generator, num_classes, categories):
    """
    Plot ROC curve and calculate AUC for the model.
    Args:
        model: Trained model.
        generator: Data generator for test images.
        num_classes: Number of classes.
        categories: List of category names.
    """
    # Get true labels and predictions
    y_true = []
    y_pred = []

    for i in range(len(generator)):
        x_batch, y_batch = generator[i]
        y_true.append(y_batch)
        y_pred.append(model.predict(x_batch, verbose=0))

    y_true = np.vstack(y_true)
    y_pred = np.vstack(y_pred)

    # Initialize plot
    plt.figure(figsize=(10, 8))
    for i in range(num_classes):
        # Compute ROC curve and AUC
        fpr, tpr, _ = roc_curve(y_true[:, i], y_pred[:, i])
        roc_auc = auc(fpr, tpr)

        # Plot each class's ROC curve
        plt.plot(fpr, tpr, label=f'Class {categories[i]} (AUC = {roc_auc:.2f})')

    # Plot random guess line
    plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')

    # Add labels, legend, and grid
    plt.title('ROC Curve with AUC')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc='lower right')
    plt.grid()

    # Show the plot
    plt.show()

    # Calculate overall micro-average AUC
    micro_auc = roc_auc_score(y_true, y_pred, average='micro')
    print(f'Micro-average AUC: {micro_auc:.2f}')

# Example usage
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model

# Load the model
model = load_model('model.h5')

# Define class categories
categories = ["glioma", "meningioma", "notumor", "pituitary"]

# Create a generator for the test set
test_datagen = ImageDataGenerator(rescale=1.0 / 255)
test_generator = test_datagen.flow_from_directory(
    "Dataset/test",
    target_size=(150, 150),
    batch_size=32,
    class_mode="categorical",
    shuffle=False
)

# Plot ROC and calculate AUC
plot_auc(model, test_generator, num_classes=len(categories), categories=categories)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Found 1368 images belonging to 4 classes.
# Micro-average AUC: 0.99

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import keras_tuner as kt

# Define the directories
train_dir = "Dataset/train"
val_dir = "Dataset/validation"
test_dir = "Dataset/test"

# Define the categories
categories = ["glioma", "meningioma", "notumor", "pituitary"]

# Visualize the distribution of tumor types in the training dataset
train_data = []
for category in categories:
    folder_path = os.path.join(train_dir, category)
    images = os.listdir(folder_path)
    count = len(images)
    train_data.append(pd.DataFrame({"Image": images, "Category": [category] * count, "Count": [count] * count}))
train_df = pd.concat(train_data, ignore_index=True)

plt.figure(figsize=(8, 6))
sns.barplot(data=train_df, x="Category", y="Count")
plt.title("Distribution of Tumor Types")
plt.xlabel("Tumor Type")
plt.ylabel("Count")
plt.show()

# Visualize sample images for each tumor type
plt.figure(figsize=(12, 8))
for i, category in enumerate(categories):
    folder_path = os.path.join(train_dir, category)
    image_path = os.path.join(folder_path, os.listdir(folder_path)[0])
    try:
        img = plt.imread(image_path)
        plt.subplot(2, 2, i + 1)
        plt.imshow(img)
        plt.title(category)
        plt.axis("off")
    except:
        continue
plt.tight_layout()
plt.show()

# Set the image size
image_size = (150, 150)

# Set the batch size and number of epochs
batch_size = 32
epochs = 50

# Data augmentation and preprocessing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode="nearest"
)

val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Create data generators
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical"
)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical"
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False
)

# Define the model-building function for hyperparameter tuning
def build_model(hp):
    model = Sequential([
        Conv2D(hp.Int("filters_1", min_value=32, max_value=128, step=32), 
               (3, 3), activation="relu", input_shape=(image_size[0], image_size[1], 3)),
        MaxPooling2D((2, 2)),
        Conv2D(hp.Int("filters_2", min_value=32, max_value=128, step=32), (3, 3), activation="relu"),
        MaxPooling2D((2, 2)),
        Conv2D(hp.Int("filters_3", min_value=32, max_value=128, step=32), (3, 3), activation="relu"),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(hp.Int("dense_units", min_value=64, max_value=256, step=64), activation="relu"),
        Dropout(hp.Float("dropout_rate", min_value=0.2, max_value=0.5, step=0.1)),
        Dense(len(categories), activation="softmax")
    ])
    
    # Compile the model
    model.compile(
        optimizer=Adam(hp.Choice("learning_rate", [1e-2, 1e-3, 1e-4])),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

# Initialize the tuner
tuner = kt.Hyperband(
    build_model,
    objective="val_accuracy",
    max_epochs=10,
    factor=3,
    directory="hyperparam_tuning",
    project_name="brain_tumor_classification"
)

# Early stopping callback
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

# Run the hyperparameter search
tuner.search(
    train_generator,
    steps_per_epoch=np.ceil(train_generator.samples / batch_size).astype(int),
    validation_data=validation_generator,
    validation_steps=np.ceil(validation_generator.samples / batch_size).astype(int),
    epochs=50,
    callbacks=[stop_early]
)

# Retrieve the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build the model with the best hyperparameters
model = tuner.hypermodel.build(best_hps)

# Train the model with the best hyperparameters
history = model.fit(
    train_generator,
    steps_per_epoch=np.ceil(train_generator.samples / batch_size).astype(int),
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=np.ceil(validation_generator.samples / batch_size).astype(int)
)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(
    test_generator, 
    steps=np.ceil(test_generator.samples / batch_size).astype(int)
)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

# Visualize training history
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Trial 2 Complete [00h 01m 06s]
#
# Best val_accuracy So Far: None
# Total elapsed time: 00h 02m 38s
#
# Search: Running Trial #3
#
# Value             |Best Value So Far |Hyperparameter
# 128               |96                |filters_1
# 32                |96                |filters_2
# 32                |96                |filters_3
# 192               |128               |dense_units
# 0.4               |0.4               |dropout_rate
# 0.01              |0.001             |learning_rate
# 2                 |2                 |tuner/epochs
# 0                 |0                 |tuner/initial_epoch
# 2                 |2                 |tuner/bracket
# 0                 |0                 |tuner/round
#
# Epoch 1/2
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 84s 549ms/step - accuracy: 0.2538 - loss: 1.9880 - val_accuracy: 0.2500 - val_loss: 1.3865
# Epoch 2/2
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 222us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# 2025-01-21 22:25:28.904595: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-01-21 22:25:28.908704: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# Traceback (most recent call last):
#   File "/Users/arsalankhan/miniconda3/lib/python3.12/site-packages/keras_tuner/src/engine/base_tuner.py", line 274, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "/Users/arsalankhan/miniconda3/lib/python3.12/site-packages/keras_tuner/src/engine/base_tuner.py", line 265, in _run_and_update_trial
#     tuner_utils.convert_to_metrics_dict(
#   File "/Users/arsalankhan/miniconda3/lib/python3.12/site-packages/keras_tuner/src/engine/tuner_utils.py", line 132, in convert_to_metrics_dict
#     [convert_to_metrics_dict(elem, objective) for elem in results]
#      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/arsalankhan/miniconda3/lib/python3.12/site-packages/keras_tuner/src/engine/tuner_utils.py", line 145, in convert_to_metrics_dict
#     best_value, _ = _get_best_value_and_best_epoch_from_history(
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/arsalankhan/miniconda3/lib/python3.12/site-packages/keras_tuner/src/engine/tuner_utils.py", line 116, in _get_best_value_and_best_epoch_from_history
#     objective_value = objective.get_value(metrics)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/arsalankhan/miniconda3/lib/python3.12/site-packages/keras_tuner/src/engine/objective.py", line 59, in get_value
#     return logs[self.name]
#            ~~~~^^^^^^^^^^^
# KeyError: 'val_accuracy'
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 137
#     134 stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)
#     136 # Run the hyperparameter search
# --> 137 tuner.search(
#     138     train_generator,
#     139     steps_per_epoch=np.ceil(train_generator.samples / batch_size).astype(int),
#     140     validation_data=validation_generator,
#     141     validation_steps=np.ceil(validation_generator.samples / batch_size).astype(int),
#     142     epochs=50,
#     143     callbacks=[stop_early]
#     144 )
#     146 # Retrieve the best hyperparameters
#     147 best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
#
# File ~/miniconda3/lib/python3.12/site-packages/keras_tuner/src/engine/base_tuner.py:235, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     233     self.on_trial_begin(trial)
#     234     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
# --> 235     self.on_trial_end(trial)
#     236 self.on_search_end()
#
# File ~/miniconda3/lib/python3.12/site-packages/keras_tuner/src/engine/base_tuner.py:339, in BaseTuner.on_trial_end(self, trial)
#     333 def on_trial_end(self, trial):
#     334     """Called at the end of a trial.
#     335
#     336     Args:
#     337         trial: A `Trial` instance.
#     338     """
# --> 339     self.oracle.end_trial(trial)
#     340     self.save()
#
# File ~/miniconda3/lib/python3.12/site-packages/keras_tuner/src/engine/oracle.py:108, in synchronized.<locals>.wrapped_func(*args, **kwargs)
#     106     LOCKS[oracle].acquire()
#     107     THREADS[oracle] = thread_name
# --> 108 ret_val = func(*args, **kwargs)
#     109 if need_acquire:
#     110     THREADS[oracle] = None
#
# File ~/miniconda3/lib/python3.12/site-packages/keras_tuner/src/engine/oracle.py:588, in Oracle.end_trial(self, trial)
#     586 if not self._retry(trial):
#     587     self.end_order.append(trial.trial_id)
# --> 588     self._check_consecutive_failures()
#     590 self._save_trial(trial)
#     591 self.save()
#
# File ~/miniconda3/lib/python3.12/site-packages/keras_tuner/src/engine/oracle.py:545, in Oracle._check_consecutive_failures(self)
#     543     consecutive_failures = 0
#     544 if consecutive_failures == self.max_consecutive_failed_trials:
# --> 545     raise RuntimeError(
#     546         "Number of consecutive failures exceeded the limit "
#     547         f"of {self.max_consecutive_failed_trials}.\n"
#     548         + (trial.message or "")
#     549     )
#
# RuntimeError: Number of consecutive failures exceeded the limit of 3.
# Traceback (most recent call last):
#   File "/Users/arsalankhan/miniconda3/lib/python3.12/site-packages/keras_tuner/src/engine/base_tuner.py", line 274, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "/Users/arsalankhan/miniconda3/lib/python3.12/site-packages/keras_tuner/src/engine/base_tuner.py", line 265, in _run_and_update_trial
#     tuner_utils.convert_to_metrics_dict(
#   File "/Users/arsalankhan/miniconda3/lib/python3.12/site-packages/keras_tuner/src/engine/tuner_utils.py", line 132, in convert_to_metrics_dict
#     [convert_to_metrics_dict(elem, objective) for elem in results]
#      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/arsalankhan/miniconda3/lib/python3.12/site-packages/keras_tuner/src/engine/tuner_utils.py", line 145, in convert_to_metrics_dict
#     best_value, _ = _get_best_value_and_best_epoch_from_history(
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/arsalankhan/miniconda3/lib/python3.12/site-packages/keras_tuner/src/engine/tuner_utils.py", line 116, in _get_best_value_and_best_epoch_from_history
#     objective_value = objective.get_value(metrics)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/arsalankhan/miniconda3/lib/python3.12/site-packages/keras_tuner/src/engine/objective.py", line 59, in get_value
#     return logs[self.name]
#            ~~~~^^^^^^^^^^^
# KeyError: 'val_accuracy'
